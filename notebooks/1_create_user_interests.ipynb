# %%
import numpy as np
import pandas as pd
import random
import scipy
from scipy import stats

# %%
data = pd.read_csv('https://raw.githubusercontent.com/VividhPandey003/newsRecomm/main/data/0_news_articles.csv?token=GHSAT0AAAAAACF4FNQBY6AYIOICPOBB5MVAZUEHMWQ')
print(data.shape)
data.head()
# Out:
# (2250, 6)
#    Article_id                                              Title  \
# 0           0  Fire at Vaishno Devi shrine complex; cash coun...
# 1           1  Had not gone to meet Nawaz Sharif, says Uddhav...
# 2           2  Corruption case: Former Haryana I-T deputy com...
# 3           3  Kannur MP K Sudhakaran appointed chief of Cong...
# 4           4  Kerala girl of Class 5 writes to CJI, lauds SC...
#
#                                          Description  \
# 0  No one was injured in the fire, which broke ou...
# 1  Uddhav Thackeray led a delegation of his cabin...
# 2  It was in 2016 that the CBI had arrested Nitin...
# 3  Sudhakaran will replace Ramachandran who had a...
# 4  Chief Justice N V Ramana responded to the Clas...
#
#                        Date Category  \
# 0   June 8, 2021 7:28:32 pm    India
# 1   June 8, 2021 6:56:40 pm    India
# 2  June 8, 2021  6:25:24 pm    India
# 3  June 8, 2021  5:04:40 pm    India
# 4  June 8, 2021  4:43:10 pm    India
#
#                                                  URL
# 0  https://indianexpress.com/article/india/vaishn...
# 1  https://indianexpress.com/article/india/had-no...
# 2  https://indianexpress.com/article/india/corrup...
# 3  https://indianexpress.com/article/india/sudhak...
# 4  https://indianexpress.com/article/india/kerala...

# %%
total_length = 2250 # dataset has 2250 rows
data = data.drop(["Category"], axis = 1)
data.head()
# Out:
#    Article_id                                              Title  \
# 0           0  Fire at Vaishno Devi shrine complex; cash coun...
# 1           1  Had not gone to meet Nawaz Sharif, says Uddhav...
# 2           2  Corruption case: Former Haryana I-T deputy com...
# 3           3  Kannur MP K Sudhakaran appointed chief of Cong...
# 4           4  Kerala girl of Class 5 writes to CJI, lauds SC...
#
#                                          Description  \
# 0  No one was injured in the fire, which broke ou...
# 1  Uddhav Thackeray led a delegation of his cabin...
# 2  It was in 2016 that the CBI had arrested Nitin...
# 3  Sudhakaran will replace Ramachandran who had a...
# 4  Chief Justice N V Ramana responded to the Clas...
#
#                        Date                                                URL
# 0   June 8, 2021 7:28:32 pm  https://indianexpress.com/article/india/vaishn...
# 1   June 8, 2021 6:56:40 pm  https://indianexpress.com/article/india/had-no...
# 2  June 8, 2021  6:25:24 pm  https://indianexpress.com/article/india/corrup...
# 3  June 8, 2021  5:04:40 pm  https://indianexpress.com/article/india/sudhak...
# 4  June 8, 2021  4:43:10 pm  https://indianexpress.com/article/india/kerala...

# %% [markdown]
# # UserID

# %%
def generator():
    session = stats.geom.rvs(size = 2250, p = 0.3) # dataset has 2250 rows
    return session

user_session = generator()

# %%
user_id = []
id = 1

for u_id in range(total_length):
    user_id.append(id)
    if u_id > 10:
        id += 1

user_id = np.array(user_id).flatten()
len(user_id)
# Out:
# 2250

# %%
data['UserId'] = user_id
print(data.shape)
# Out:
# (2250, 6)

# %%
session_id = []
i = 1

for s_id in range(total_length):
    session_id.append(i)
    if s_id > 15:
        i += 1

session_id = np.array(session_id).flatten()
len(session_id)
# Out:
# 2250

# %%
data['SessionId'] = session_id
print(data.shape)
# Out:
# (2250, 7)

# %% [markdown]
# # Article Rank

# %%
article_rank = []
i = 1
for ar in range(total_length):
    article_rank.append(i)
    i += 1

    if i>10:
        i = 1
len(article_rank)
# Out:
# 2250

# %%
data['Article Rank'] = article_rank

# %% [markdown]
# # Click status

# %%
click_session = []
for c in range(total_length):
    click_session.append(random.choice([True, False]))

len(click_session)
# Out:
# 2250

# %%
data['Click'] = click_session

# %% [markdown]
# # Time taken

# %%
time_session = []
for t in range(total_length):
    time_session.append(np.random.randint(10, 100))

# if click is false set time to 0

for i in range(total_length):
    if click_session[i] is True:
        time_session[i] = time_session[i]
    else:
        time_session[i] = 0

len(time_session)
# Out:
# 2250

# %%
data['Time Spent (seconds)'] = time_session

# %%
data.head()
# Out:
#    Article_id                                              Title  \
# 0           0  Fire at Vaishno Devi shrine complex; cash coun...
# 1           1  Had not gone to meet Nawaz Sharif, says Uddhav...
# 2           2  Corruption case: Former Haryana I-T deputy com...
# 3           3  Kannur MP K Sudhakaran appointed chief of Cong...
# 4           4  Kerala girl of Class 5 writes to CJI, lauds SC...
#
#                                          Description  \
# 0  No one was injured in the fire, which broke ou...
# 1  Uddhav Thackeray led a delegation of his cabin...
# 2  It was in 2016 that the CBI had arrested Nitin...
# 3  Sudhakaran will replace Ramachandran who had a...
# 4  Chief Justice N V Ramana responded to the Clas...
#
#                        Date  \
# 0   June 8, 2021 7:28:32 pm
# 1   June 8, 2021 6:56:40 pm
# 2  June 8, 2021  6:25:24 pm
# 3  June 8, 2021  5:04:40 pm
# 4  June 8, 2021  4:43:10 pm
#
#                                                  URL  UserId  SessionId  \
# 0  https://indianexpress.com/article/india/vaishn...       1          1
# 1  https://indianexpress.com/article/india/had-no...       1          1
# 2  https://indianexpress.com/article/india/corrup...       1          1
# 3  https://indianexpress.com/article/india/sudhak...       1          1
# 4  https://indianexpress.com/article/india/kerala...       1          1
#
#    Article Rank  Click  Time Spent (seconds)
# 0             1  False                     0
# 1             2   True                    37
# 2             3  False                     0
# 3             4   True                    66
# 4             5  False                     0

# %%
data.tail()
# Out:
#       Article_id                                              Title  \
# 2245        2245  Malaika Arora shares yoga asanas for healthy, ...
# 2246        2246  COVID-19 diet: Khichdi is a ‘safe’ option; oth...
# 2247        2247  ‘Keep listening. The world wants to hear your ...
# 2248        2248  Forget cold drinks, switch to refreshing bael ...
# 2249        2249  ‘Love wins’: Rita Wilson and Tom Hanks celebra...
#
#                                             Description  \
# 2245  Malaika Arora shares three yoga poses that can...
# 2246  One should make sure that the meals are hot an...
# 2247  "Not every problem has a high-tech solution. N...
# 2248  Bael sherbet, a delightful and soothing detox ...
# 2249  The 'Forest Gump' actor nursed a crush on Wils...
#
#                          Date  \
# 2245  May 3, 2021  2:04:14 pm
# 2246   May 3, 2021 9:10:55 am
# 2247   May 3, 2021 8:15:33 am
# 2248  May 2, 2021 10:30:54 pm
# 2249   May 2, 2021 9:40:39 pm
#
#                                                     URL  UserId  SessionId  \
# 2245  https://indianexpress.com/article/lifestyle/fi...    2235       2230
# 2246  https://indianexpress.com/article/lifestyle/fo...    2236       2231
# 2247  https://indianexpress.com/article/lifestyle/li...    2237       2232
# 2248  https://indianexpress.com/article/lifestyle/fo...    2238       2233
# 2249  https://indianexpress.com/article/lifestyle/fe...    2239       2234
#
#       Article Rank  Click  Time Spent (seconds)
# 2245             6  False                     0
# 2246             7  False                     0
# 2247             8  False                     0
# 2248             9  False                     0
# 2249            10   True                    45

# %%
for i in range(total_length):
    if time_session[i] == 0:
        data = data.drop(i)
        total_length -= 1
print(total_length)
# Out:
# 1166

# %%
data.head()
# Out:
#     Article_id                                              Title  \
# 1            1  Had not gone to meet Nawaz Sharif, says Uddhav...
# 3            3  Kannur MP K Sudhakaran appointed chief of Cong...
# 6            6  Uddhav Thackeray meets PM Modi; discusses Mara...
# 7            7  New Covid-19 vaccination guidelines out, alloc...
# 10          10  Why govt used COVID-19 data as ‘propaganda too...
#
#                                           Description  \
# 1   Uddhav Thackeray led a delegation of his cabin...
# 3   Sudhakaran will replace Ramachandran who had a...
# 6   Deputy Chief Minister and senior NCP leader Aj...
# 7   As per the revised guidelines, the Centre will...
# 10  Congress leader Priyanka Gandhi Vadra, in her ...
#
#                         Date  \
# 1    June 8, 2021 6:56:40 pm
# 3   June 8, 2021  5:04:40 pm
# 6    June 8, 2021 2:25:23 pm
# 7   June 8, 2021  4:27:29 pm
# 10  June 8, 2021 12:21:43 pm
#
#                                                   URL  UserId  SessionId  \
# 1   https://indianexpress.com/article/india/had-no...       1          1
# 3   https://indianexpress.com/article/india/sudhak...       1          1
# 6   https://indianexpress.com/article/india/mahara...       1          1
# 7   https://indianexpress.com/article/india/govt-r...       1          1
# 10  https://indianexpress.com/article/india/govt-c...       1          1
#
#     Article Rank  Click  Time Spent (seconds)
# 1              2   True                    37
# 3              4   True                    66
# 6              7   True                    12
# 7              8   True                    51
# 10             1   True                    39

# %%
data.tail()
# Out:
#       Article_id                                              Title  \
# 2238        2238  FSSAI recommends including soy foods in your d...
# 2240        2240  White jamun: Why you must try this lesser-know...
# 2243        2243  Bhagyashree pens note on ‘prioritising one’s o...
# 2244        2244  How learning about your genes can help with yo...
# 2249        2249  ‘Love wins’: Rita Wilson and Tom Hanks celebra...
#
#                                             Description  \
# 2238  Gluten-free, low fat, and high fibre soy foods...
# 2240  Here's why seasonal fruits like white jamun sh...
# 2243  "Even if one is isolated, one needn't feel or ...
# 2244  Genetics influences our food tastes and sensit...
# 2249  The 'Forest Gump' actor nursed a crush on Wils...
#
#                          Date  \
# 2238   May 3, 2021 3:50:11 pm
# 2240   May 3, 2021 2:10:53 pm
# 2243  May 3, 2021 11:40:23 am
# 2244  May 3, 2021  2:03:38 pm
# 2249   May 2, 2021 9:40:39 pm
#
#                                                     URL  UserId  SessionId  \
# 2238  https://indianexpress.com/article/lifestyle/he...    2228       2223
# 2240  https://indianexpress.com/article/lifestyle/he...    2230       2225
# 2243  https://indianexpress.com/article/lifestyle/he...    2233       2228
# 2244  https://indianexpress.com/article/lifestyle/he...    2234       2229
# 2249  https://indianexpress.com/article/lifestyle/fe...    2239       2234
#
#       Article Rank  Click  Time Spent (seconds)
# 2238             9   True                    99
# 2240             1   True                    91
# 2243             4   True                    29
# 2244             5   True                    83
# 2249            10   True                    45

# %%
data.shape
# Out:
# (1166, 10)

# %%
data.to_csv('https://raw.githubusercontent.com/VividhPandey003/newsRecomm/main/data/2_user_interest.csv?token=GHSAT0AAAAAACF4FNQBDA55YGMO3SPIVYAYZUEHN2A')

# %% [markdown]
# ## For makinng Recommendations based on Ratings, we need to generate Ratings
#
# Method followed:
#
#     1. 0 rating for least interesting article
#
#     2. 5 rating for most interesting article

# %%
ratings = []
for r in range(total_length):
    ratings.append(np.random.randint(1, 6))

len(ratings)
# Out:
# 1166

# %% [markdown]
# ### Adding Rating Dataframe

# %%
data['Ratings'] = ratings
data.head()
# Out:
#     Article_id                                              Title  \
# 1            1  Had not gone to meet Nawaz Sharif, says Uddhav...
# 3            3  Kannur MP K Sudhakaran appointed chief of Cong...
# 6            6  Uddhav Thackeray meets PM Modi; discusses Mara...
# 7            7  New Covid-19 vaccination guidelines out, alloc...
# 10          10  Why govt used COVID-19 data as ‘propaganda too...
#
#                                           Description  \
# 1   Uddhav Thackeray led a delegation of his cabin...
# 3   Sudhakaran will replace Ramachandran who had a...
# 6   Deputy Chief Minister and senior NCP leader Aj...
# 7   As per the revised guidelines, the Centre will...
# 10  Congress leader Priyanka Gandhi Vadra, in her ...
#
#                         Date  \
# 1    June 8, 2021 6:56:40 pm
# 3   June 8, 2021  5:04:40 pm
# 6    June 8, 2021 2:25:23 pm
# 7   June 8, 2021  4:27:29 pm
# 10  June 8, 2021 12:21:43 pm
#
#                                                   URL  UserId  SessionId  \
# 1   https://indianexpress.com/article/india/had-no...       1          1
# 3   https://indianexpress.com/article/india/sudhak...       1          1
# 6   https://indianexpress.com/article/india/mahara...       1          1
# 7   https://indianexpress.com/article/india/govt-r...       1          1
# 10  https://indianexpress.com/article/india/govt-c...       1          1
#
#     Article Rank  Click  Time Spent (seconds)  Ratings
# 1              2   True                    37        3
# 3              4   True                    66        2
# 6              7   True                    12        2
# 7              8   True                    51        5
# 10             1   True                    39        1

# %%
ratings_data = data.drop(columns = ['Description', 'Date', 'URL', 'Click'])
ratings_data.head()
# Out:
#     Article_id                                              Title  UserId  \
# 1            1  Had not gone to meet Nawaz Sharif, says Uddhav...       1
# 3            3  Kannur MP K Sudhakaran appointed chief of Cong...       1
# 6            6  Uddhav Thackeray meets PM Modi; discusses Mara...       1
# 7            7  New Covid-19 vaccination guidelines out, alloc...       1
# 10          10  Why govt used COVID-19 data as ‘propaganda too...       1
#
#     SessionId  Article Rank  Time Spent (seconds)  Ratings
# 1           1             2                    37        3
# 3           1             4                    66        2
# 6           1             7                    12        2
# 7           1             8                    51        5
# 10          1             1                    39        1

# %%
ratings_data.to_csv('https://raw.githubusercontent.com/VividhPandey003/newsRecomm/main/data/3_user_rated_articles.csv?token=GHSAT0AAAAAACF4FNQAMAGPEBRJTELMNCAEZUEHOPA')
