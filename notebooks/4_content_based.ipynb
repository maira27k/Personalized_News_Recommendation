# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import string
import re

# %%
import gensim
from gensim import corpora, models, similarities

import nltk
from nltk.corpus import stopwords

# %%
import scipy
from scipy.spatial.distance import cdist
from scipy.sparse import csr_matrix
from scipy.sparse.linalg import svds
from scipy.linalg import svd

# %%
from sklearn.cluster import KMeans
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import silhouette_score, silhouette_samples
from sklearn.metrics.pairwise import cosine_similarity, linear_kernel
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Reading data sets
#
# 1. news_articles - Contains raw articles without user data amalgamation
# 2. user_interest - Contains raw articles mixed with user data as an amalgamation with ArticleID as Foreign Key

# %% [markdown]
# ## news_articles

# %%
data = pd.read_csv('https://raw.githubusercontent.com/VividhPandey003/newsRecomm/main/data/0_news_articles.csv?token=GHSAT0AAAAAACF4FNQBY6AYIOICPOBB5MVAZUEHMWQ')
data.head()
# Out:
#    Article_id                                              Title  \
# 0           0  Fire at Vaishno Devi shrine complex; cash coun...
# 1           1  Had not gone to meet Nawaz Sharif, says Uddhav...
# 2           2  Corruption case: Former Haryana I-T deputy com...
# 3           3  Kannur MP K Sudhakaran appointed chief of Cong...
# 4           4  Kerala girl of Class 5 writes to CJI, lauds SC...
#
#                                          Description  \
# 0  No one was injured in the fire, which broke ou...
# 1  Uddhav Thackeray led a delegation of his cabin...
# 2  It was in 2016 that the CBI had arrested Nitin...
# 3  Sudhakaran will replace Ramachandran who had a...
# 4  Chief Justice N V Ramana responded to the Clas...
#
#                        Date Category  \
# 0   June 8, 2021 7:28:32 pm    India
# 1   June 8, 2021 6:56:40 pm    India
# 2  June 8, 2021  6:25:24 pm    India
# 3  June 8, 2021  5:04:40 pm    India
# 4  June 8, 2021  4:43:10 pm    India
#
#                                                  URL
# 0  https://indianexpress.com/article/india/vaishn...
# 1  https://indianexpress.com/article/india/had-no...
# 2  https://indianexpress.com/article/india/corrup...
# 3  https://indianexpress.com/article/india/sudhak...
# 4  https://indianexpress.com/article/india/kerala...

# %% [markdown]
# ## user_interest

# %%
user = pd.read_csv('https://raw.githubusercontent.com/VividhPandey003/newsRecomm/main/data/2_user_interest.csv?token=GHSAT0AAAAAACF4FNQBDA55YGMO3SPIVYAYZUEHN2A')
print(user.shape)
user.drop(columns= user.columns[0],
        axis=1,
        inplace=True)
user.head()
# Out:
# (1187, 11)
#    Article_id                                              Title  \
# 0           0  Fire at Vaishno Devi shrine complex; cash coun...
# 1           2  Corruption case: Former Haryana I-T deputy com...
# 2           5  Madhya Pradesh govt gets HC notice on communal...
# 3           6  Uddhav Thackeray meets PM Modi; discusses Mara...
# 4           7  New Covid-19 vaccination guidelines out, alloc...
#
#                                          Description  \
# 0  No one was injured in the fire, which broke ou...
# 1  It was in 2016 that the CBI had arrested Nitin...
# 2  Hearing a petition on the matter filed by form...
# 3  Deputy Chief Minister and senior NCP leader Aj...
# 4  As per the revised guidelines, the Centre will...
#
#                        Date  \
# 0   June 8, 2021 7:28:32 pm
# 1  June 8, 2021  6:25:24 pm
# 2  June 8, 2021  4:10:12 pm
# 3   June 8, 2021 2:25:23 pm
# 4  June 8, 2021  4:27:29 pm
#
#                                                  URL  UserId  SessionId  \
# 0  https://indianexpress.com/article/india/vaishn...       1          1
# 1  https://indianexpress.com/article/india/corrup...       1          1
# 2  https://indianexpress.com/article/india/mp-hc-...       1          1
# 3  https://indianexpress.com/article/india/mahara...       1          1
# 4  https://indianexpress.com/article/india/govt-r...       1          1
#
#    Article Rank  Click  Time Spent (seconds)
# 0             1   True                    81
# 1             3   True                    49
# 2             6   True                    19
# 3             7   True                    33
# 4             8   True                    71

# %% [markdown]
# ## Content Based

# %%
vectorizer = TfidfVectorizer(analyzer = 'word')
tfidf_matrix = vectorizer.fit_transform(user['Title'])
tfidf_matrix.shape
# Out:
# (1187, 4589)

# %%
# cosine-similarity (linear kernel)
cosine_similarity = linear_kernel(tfidf_matrix, tfidf_matrix)

# index of Title
indices = pd.Series(user['Title'].index)

# %%
# making predictions

def recommendation(index, method):
    id = indices[index]

    # fetching the top 10 articles

    similarity_score = list(enumerate(method[id]))
    similarity_score = sorted(similarity_score, key = lambda x: x[1], reverse = True)
    similarity_score = similarity_score[1:11]

    # get the article index
    news_index = [i[0] for i in similarity_score]

    # returning the top 10 most similar books
    return user['Title'].iloc[news_index]

# %%
# obtaining random input
input = user.sample()
input
# Out:
#      Article_id                                              Title  \
# 290         552  Abduction by ‘fake CBI officers’: Kolkata Poli...
#
#                                            Description  \
# 290  “Three persons have been arrested. There are m...
#
#                          Date  \
# 290  May 27, 2021  7:20:22 am
#
#                                                    URL  UserId  SessionId  \
# 290  https://indianexpress.com/article/india/abduct...     542        537
#
#      Article Rank  Click  Time Spent (seconds)
# 290             3   True                    97

# %%
# passing the input
recommendation(224, cosine_similarity)
# Out:
# 291     Congress says new IT rules dire, drastic, drac...
# 1004    Four months after giving birth, Ashley Graham ...
# 215     Take action against institutions giving Covid ...
# 64      Aligarh hooch tragedy: Congress slams BJP govt...
# 271            Kerala Congress unit chief wants to resign
# 333     ‘Toolkit’ probe: Police notice to its leaders,...
# 317     Coronavirus India Highlights: Noting stabilisa...
# 337     ‘Manipulated Media’ tag, Delhi Police’s visit:...
# 582     Naseem Shah set to join bio-secure bubble for ...
# 623     ‘Moin Khan scolded me as well’: Younis Khan re...
# Name: Title, dtype: object
